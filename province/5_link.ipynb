# %% [markdown]
# ## read url from csv

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
url = pd.read_csv('output/url.csv')[13:]

# %%
# new_url = pd.read_csv('output/url.csv')

# %%
# name_set = pd.read_csv('')

# %% [markdown]
# ## scraping link from sidebar

# %%
import urllib
import pandas as pd
from bs4 import BeautifulSoup

interest_links = []
web_links = []

for i in url['old_url']:
    ui = 'http://' + i
    f = urllib.request.urlopen(ui)
    left_side = BeautifulSoup(f.read(), 'html.parser').find('aside',attrs={"id": "sidebar-left"})

    all_link = []
    left_block = left_side.find_all(attrs={"class": "block-block"})
    for block in left_block:
        link_in_block = block.find_all('a')
        if (len(link_in_block) > 0):
            all_link+=link_in_block

    print(i,':',len(all_link))

    interest_link = []
    web_link = []

    for link in all_link:
        if link['href'][0:4] == 'http':
            interest_link.append(link['href'])
        else:
            web_link.append(link['href'])

    interest_links.append(interest_link)
    web_links.append(web_link)
# Out:
# saraburi.mol.go.th : 34
# singburi.mol.go.th : 31
# suphanburi.mol.go.th : 4
# angthong.mol.go.th : 18
# chanthaburi.mol.go.th : 8
# chachoengsao.mol.go.th : 11
# chonburi.mol.go.th : 4
# trat.mol.go.th : 12
# nakhonnayok.mol.go.th : 13
# prachinburi.mol.go.th : 18
# rayong.mol.go.th : 19
# sakaeo.mol.go.th : 10
# kalasin.mol.go.th : 16
# khonkaen.mol.go.th : 20
# chaiyaphum.mol.go.th : 9
# nakhonphanom.mol.go.th : 15
# nakhonratchasima.mol.go.th : 13
# buengkan.mol.go.th : 3
# buriram.mol.go.th : 14
# mahasarakham.mol.go.th : 15
# mukdahan.mol.go.th : 3
# yasothon.mol.go.th : 16
# roiet.mol.go.th : 9
# loei.mol.go.th : 9
# sisaket.mol.go.th : 22
# sakonnakhon.mol.go.th : 8
# surin.mol.go.th : 12
# nongkhai.mol.go.th : 10
# nongbualamphu.mol.go.th : 3
# amnatcharoen.mol.go.th : 3
# udonthani.mol.go.th : 3
# ubonratchathani.mol.go.th : 14
# kamphaengphet.mol.go.th : 10
# phetchabun.mol.go.th : 7
# chiangrai.mol.go.th : 4
# chiangmai.mol.go.th : 12
# tak.mol.go.th : 3
# nakhonsawan.mol.go.th : 11
# nan.mol.go.th : 13
# phayao.mol.go.th : 3
# phichit.mol.go.th : 17
# phitsanulok.mol.go.th : 4
# phrae.mol.go.th : 3
# maehongson.mol.go.th : 10
# lampang.mol.go.th : 21
# lamphun.mol.go.th : 23
# sukhothai.mol.go.th : 3
# uttaradit.mol.go.th : 5
# uthaithani.mol.go.th : 3
# krabi.mol.go.th : 24
# chumphon.mol.go.th : 3
# trang.mol.go.th : 3
# nakhonsithammarat.mol.go.th : 10
# narathiwat.mol.go.th : 17
# pattani.mol.go.th : 14
# phangnga.mol.go.th : 20
# phatthalung.mol.go.th : 20
# phuket.mol.go.th : 10
# yala.mol.go.th : 16
# ranong.mol.go.th : 3
# songkhla.mol.go.th : 15
# satun.mol.go.th : 17
# suratthani.mol.go.th : 25

# %%
url['interest_links'] = interest_links
url['web_links'] = web_links

# %%
url.to_csv('output/interest_link/link.csv',index=False)

# %% [markdown]
# # Cleaning Data

# %%
from ast import literal_eval

# %%
all_link = pd.read_csv('output/interest_link/link_v3.csv')
all_link['length'] = all_link['interest_links'].apply(lambda x : len(literal_eval(x)) ) + all_link['web_links'].apply(lambda x : len(literal_eval(x)) )
all_link[['old_url','length']]
# Out:
#                         old_url  length
# 0            saraburi.mol.go.th      34
# 1            singburi.mol.go.th      31
# 2            angthong.mol.go.th      18
# 3         chanthaburi.mol.go.th       8
# 4        chachoengsao.mol.go.th      11
# 5            chonburi.mol.go.th       4
# 6                trat.mol.go.th      12
# 7         nakhonnayok.mol.go.th      13
# 8         prachinburi.mol.go.th      18
# 9              rayong.mol.go.th      19
# 10             sakaeo.mol.go.th      10
# 11            kalasin.mol.go.th      16
# 12           khonkaen.mol.go.th      20
# 13         chaiyaphum.mol.go.th       9
# 14       nakhonphanom.mol.go.th      15
# 15   nakhonratchasima.mol.go.th      13
# 16           buengkan.mol.go.th       3
# 17            buriram.mol.go.th      14
# 18       mahasarakham.mol.go.th      15
# 19           mukdahan.mol.go.th       3
# 20           yasothon.mol.go.th      16
# 21              roiet.mol.go.th       9
# 22               loei.mol.go.th       9
# 23            sisaket.mol.go.th      22
# 24        sakonnakhon.mol.go.th       8
# 25              surin.mol.go.th      12
# 26           nongkhai.mol.go.th      10
# 27      nongbualamphu.mol.go.th       3
# 28       amnatcharoen.mol.go.th       3
# 29          udonthani.mol.go.th       3
# 30    ubonratchathani.mol.go.th      14
# 31      kamphaengphet.mol.go.th      10
# 32         phetchabun.mol.go.th       7
# 33          chiangrai.mol.go.th       4
# 34          chiangmai.mol.go.th      12
# 35                tak.mol.go.th       3
# 36        nakhonsawan.mol.go.th      11
# 37                nan.mol.go.th      13
# 38             phayao.mol.go.th       3
# 39            phichit.mol.go.th      17
# 40        phitsanulok.mol.go.th       4
# 41              phrae.mol.go.th       3
# 42         maehongson.mol.go.th      10
# 43            lampang.mol.go.th      21
# 44            lamphun.mol.go.th      23
# 45          sukhothai.mol.go.th       3
# 46          uttaradit.mol.go.th       5
# 47         uthaithani.mol.go.th       3
# 48              krabi.mol.go.th      24
# 49           chumphon.mol.go.th       3
# 50              trang.mol.go.th       3
# 51  nakhonsithammarat.mol.go.th      10
# 52         narathiwat.mol.go.th      17
# 53            pattani.mol.go.th      14
# 54           phangnga.mol.go.th      20
# 55        phatthalung.mol.go.th      20
# 56             phuket.mol.go.th      10
# 57               yala.mol.go.th      16
# 58             ranong.mol.go.th       3
# 59           songkhla.mol.go.th      15
# 60              satun.mol.go.th      17
# 61         suratthani.mol.go.th      25

# %%
new_df = pd.read_csv('output/interest_link/link_v3.csv')
new_int_link_df = pd.read_csv('data/name_interest_link.csv')
new_web_link_df = pd.read_csv('data/name_web_link.csv')

# %% [markdown]
# ---------------------

# %%
# for each province 
prov_data = new_df.loc[9]

prov_url = prov_data['new_url']
print(prov_url)
old_prov_url = prov_data['old_url']
prov_int_link = literal_eval(prov_data['interest_links'])
prov_web_link = literal_eval(prov_data['web_links'])
# Out:
# rayong2.mol.go.th

# %% [markdown]
# ### Interest Link

# %%
### Interest Link
action_url = []
int_link = []
name_of_link = []

for i in prov_int_link:
    action_url.append('https://'+prov_url+'/wp-admin/post-new.php?post_type=interesting_links')
    int_link.append(i)

    name = 'x'
    for index,k in new_int_link_df.iterrows():
        if k['url'] in i:
            name = k['name']
    name_of_link.append(name)

interest_link_df = pd.DataFrame({'name': name_of_link, 'link':  int_link,'action_url': action_url})
interest_link_df['index'] = interest_link_df.index
interest_link_df = interest_link_df.sort_values(by=['index'], ascending=False)
interest_link_df.to_csv('output/interest_link/add_new_link_to_province.csv',index=False)
interest_link_df
# Out:
#                                              name  \
# 2                                               x
# 1                                               x
# 0  ผลิตภัณฑ์โครงการแก้ปัญหาความเดือดร้อนด้านอาชีพ
#
#                                         link  \
# 2             http://web.ocsc.go.th/forking/
# 1  http://www.suphanburi.mol.go.th/node/2636
# 0  http://labourproduct.mol.go.th/suphanburi
#
#                                           action_url  index
# 2  https://suphanburi2.mol.go.th/wp-admin/post-ne...      2
# 1  https://suphanburi2.mol.go.th/wp-admin/post-ne...      1
# 0  https://suphanburi2.mol.go.th/wp-admin/post-ne...      0

# %% [markdown]
# ### Web Link

# %%
new_web_link_df
# Out:
#                 name    url
# 0  ลิ้งที่เกี่ยวข้อง  /link

# %%
### Web Link
action_url2 = []
web_link = []
name_of_web_link = []

for j in prov_web_link:
    print(j)
    if j != '/../calendar':
        action_url2.append('https://'+prov_url+'/wp-admin/post-new.php?post_type=web_links')
        old_web_link = 'http://' + old_prov_url + '/' + j.split('/')[-1]
        web_link.append(old_web_link)

        name = 'x'
        for index,m in new_web_link_df.iterrows():
            if m['url'] in j:
                name = m['name']
        name_of_web_link.append(name)

web_link_df = pd.DataFrame({'name': name_of_web_link, 'link':  web_link,'action_url': action_url2})
web_link_df['index'] = web_link_df.index
web_link_df = web_link_df.sort_values(by=['index'], ascending=False)
web_link_df.to_csv('output/web_link/add_web_link.csv',index=False)
web_link_df
# Out:
# /../link
#                 name                              link  \
# 0  ลิ้งที่เกี่ยวข้อง  http://suphanburi.mol.go.th/link
#
#                                           action_url  index
# 0  https://suphanburi2.mol.go.th/wp-admin/post-ne...      0

# %%
pd.read_csv('output/interest_link/add_new_link_to_province.csv')
# Out:
#                                                 name  \
# 0               ศูนย์ข้อมูลสารสนเทศด้านแรงงานจังหวัด
# 1                                      สำนักงาน ก.พ.
# 2       ดูเรื่องร้องทุกข์ ร้องเรียน ของกระทรวงแรงงาน
# 3  ยื่นเรื่องร้องทุกข์ ร้องเรียนผ่านทางกระทรวงแรงงาน
# 4  ยื่นเรื่องร้องทุกข์ ร้องเรียนผ่านทางศูนย์ดำรงธ...
# 5     ผลิตภัณฑ์โครงการแก้ปัญหาความเดือดร้อนด้านอาชีพ
#
#                                                 link  \
# 0  http://analytic.nlic.mol.go.th/analytics/saw.d...
# 1                     http://web.ocsc.go.th/forking/
# 2          http://www.mol.go.th/anonymouse/complaint
# 3  http://cos.mol.go.th//pt/Petition/WebPetitionP...
# 4  https://www.facebook.com/%E0%B8%A8%E0%B8%B9%E0...
# 5          http://labourproduct.mol.go.th/suphanburi
#
#                                           action_url  index
# 0  https://suphanburi2.mol.go.th/wp-admin/post-ne...      3
# 1  https://suphanburi2.mol.go.th/wp-admin/post-ne...      2
# 2  https://suphanburi2.mol.go.th/wp-admin/post-ne...     13
# 3  https://suphanburi2.mol.go.th/wp-admin/post-ne...     12
# 4  https://suphanburi2.mol.go.th/wp-admin/post-ne...     11
# 5  https://suphanburi2.mol.go.th/wp-admin/post-ne...      0

# %%
pd.read_csv('output/web_link/add_web_link.csv')
# Out:
#                 name                              link  \
# 0  ลิ้งที่เกี่ยวข้อง  http://suphanburi.mol.go.th/link
#
#                                           action_url  index
# 0  https://suphanburi2.mol.go.th/wp-admin/post-ne...      0
