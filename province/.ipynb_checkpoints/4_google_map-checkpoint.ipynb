# %% [markdown]
# ## read url from csv

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
address = pd.read_csv('output/address_v4.csv')[['address','new_url']]
address.head()
# Out:
#                                              address  \
# 0  สำนักงานแรงงานจังหวัดปทุมธานี ศาลากลางจังหวัด ...
# 1  สำนักงานแรงงานจังหวัดประจวบคีรีขันธ์ ศาลากลางจ...
# 2  สำนักงานแรงงานจังหวัดพระนครศรีอยุธยา ชั้น3 อาค...
# 3  สำนักงานแรงงานจังหวัดเพชรบุรี 2/105-106 ตำบลไร...
# 4  สำนักงานแรงงานจังหวัดราชบุรี  75/24 หมู่ที่ 3 ...
#
#                         new_url
# 0        pathumthani2.mol.go.th
# 1  prachuapkhirikhan2.mol.go.th
# 2          ayutthaya2.mol.go.th
# 3        phetchaburi2.mol.go.th
# 4         ratchaburi2.mol.go.th

# %%
address.to_csv('output/google_map.csv', index=False)

# %% [markdown]
# ## Get Iframe from Google Map API

# %%
pd.read_csv('output/google_map_v1.csv')
# Out:
#                                               address  \
# 0   สำนักงานแรงงานจังหวัดประจวบคีรีขันธ์ ศาลากลางจ...
# 1   สำนักงานแรงงานจังหวัดพระนครศรีอยุธยา ชั้น3 อาค...
# 2   สำนักงานแรงงานจังหวัดเพชรบุรี 2/105-106 ตำบลไร...
# 3   สำนักงานแรงงานจังหวัดราชบุรี  75/24 หมู่ที่ 3 ...
# 4   สำนักงานแรงงานจังหวัดลพบุรี ศาลากลางจังหวัด (ห...
# 5   สำนักงานแรงงานจังหวัดสมุทรปราการ 1636 หมู่4 ถน...
# 6   สำนักงานแรงงานจังหวัดสมุทรสงคราม ศาลากลางจังหว...
# 7   สำนักงานแรงงานจังหวัดสมุทรสาคร ศาลากลางจังหวัด...
# 8   สำนักงานแรงงานจังหวัดสระบุรี ศาลากลางจังหวัดสร...
# 9   สำนักงานแรงงานจังหวัดสิงห์บุรี ศาลากลางจังหวัด...
# 10  สำนักงานแรงงานจังหวัดสุพรรณบุรี ศาลากลางจังหวั...
# 11  สำนักงานแรงงานจังหวัดอ่างทอง ศาลากลางจังหวัด ช...
# 12  สำนักงานแรงงานจังหวัดจันทบุรี 1212/21 ถนน่าแฉล...
# 13  สำนักงานแรงงานจังหวัดฉะเชิงเทรา ศาลากลางจังหวั...
# 14  สำนักงานแรงงานจังหวัดชลบุรี ศาลากลางจังหวัด ถน...
# 15  สำนักงานแรงงานจังหวัดตราด ศาลากลางจังหวัด ชั้น...
# ...
